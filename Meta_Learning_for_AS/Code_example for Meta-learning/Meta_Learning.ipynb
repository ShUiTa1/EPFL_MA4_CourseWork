# %% [markdown]
# ## This is a tutorial code example for Meta-learning Topic.

# %%
# import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 print(torch.__version__)
#       3 print(torch.cuda.is_available())
#
# File c:\Application\TasksList\EPFL_related\EPFL_MA4\Meta_Learning_for_AS\Code_example for Meta-learning\.venv\Lib\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# ...
